# %%
import pandas as pd
from pathlib import Path

DATA_DIR = Path("data")
for file in DATA_DIR.rglob("*"):
    if file.is_file():
        print(file)

# Load links
# links = pd.read_csv(
#     DATA_DIR / "links.tsv",
#     sep="\t",
#     comment="#",
#     names=["source", "target"]
# )

# # Build directed graph
# G = nx.from_pandas_edgelist(
#     links,
#     source="source",
#     target="target",
#     create_using=nx.DiGraph()
# )

# print("Nodes:", G.number_of_nodes())
# print("Edges:", G.number_of_edges())

# # Compute PageRank
# pagerank_scores = nx.pagerank(G, alpha=0.85)

# # Load finished paths
# paths = pd.read_csv(
#     DATA_DIR / "paths_finished.tsv",
#     sep="\t",
#     comment="#",
#     header=None
# )

# paths.head()
# Out:
# data/wikispeedia_paths-and-graph.tar.gz
# data/wikispeedia_articles_plaintext.tar.gz
# data/wikispeedia_articles_html.tar.gz
